# %%
import pandas as pd
data = pd.read_csv("./nyc_squirrels.csv")
print('Number of instances = %d' % (data.shape[0]))
print('Number of attributes = %d' % (data.shape[1]))
data.head()
# Out:
# Number of instances = 3023
# Number of attributes = 36
#         long        lat unique_squirrel_id hectare shift      date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    hectare_squirrel_number       age primary_fur_color highlight_fur_color  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#    ... approaches indifferent runs_from other_interactions  \
# 0  ...      False       False     False                NaN
# 1  ...      False       False      True                 me
# 2  ...      False        True     False                NaN
# 3  ...      False       False      True                NaN
# 4  ...      False       False     False                NaN
#
#                                        lat_long  zip_codes  \
# 0    POINT (-73.9561344937861 40.7940823884086)        NaN
# 1  POINT (-73.9570437717691 40.794850940803904)        NaN
# 2   POINT (-73.9768311751004 40.76671780725581)        NaN
# 3    POINT (-73.9757249834141 40.7697032606755)        NaN
# 4     POINT (-73.9593126695714 40.797533370163)        NaN
#
#    community_districts  borough_boundaries  city_council_districts  \
# 0                   19                   4                      19
# 1                   19                   4                      19
# 2                   19                   4                      19
# 3                   19                   4                      19
# 4                   19                   4                      19
#
#    police_precincts
# 0                13
# 1                13
# 2                13
# 3                13
# 4                13
#
# [5 rows x 36 columns]

# %%
import numpy as np
print('Number of rows before discarding duplicates = %d' % (data.shape[0]))
data = data.drop_duplicates(subset=['unique_squirrel_id'])
print('Number of rows after discarding duplicates = %d' % (data.shape[0]))
data.head()
# Out:
# Number of rows before discarding duplicates = 3023
# Number of rows after discarding duplicates = 3018
#         long        lat unique_squirrel_id hectare shift      date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    hectare_squirrel_number       age primary_fur_color highlight_fur_color  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#    ... approaches indifferent runs_from other_interactions  \
# 0  ...      False       False     False                NaN
# 1  ...      False       False      True                 me
# 2  ...      False        True     False                NaN
# 3  ...      False       False      True                NaN
# 4  ...      False       False     False                NaN
#
#                                        lat_long  zip_codes  \
# 0    POINT (-73.9561344937861 40.7940823884086)        NaN
# 1  POINT (-73.9570437717691 40.794850940803904)        NaN
# 2   POINT (-73.9768311751004 40.76671780725581)        NaN
# 3    POINT (-73.9757249834141 40.7697032606755)        NaN
# 4     POINT (-73.9593126695714 40.797533370163)        NaN
#
#    community_districts  borough_boundaries  city_council_districts  \
# 0                   19                   4                      19
# 1                   19                   4                      19
# 2                   19                   4                      19
# 3                   19                   4                      19
# 4                   19                   4                      19
#
#    police_precincts
# 0                13
# 1                13
# 2                13
# 3                13
# 4                13
#
# [5 rows x 36 columns]

# %%
print('Number of instances = %d' % data.shape[0])
print('Number of attributes = %d' % data.shape[1])

print('Number of missing values:')
for col in data.columns:
    print('\t%s: %d' % (col, data[col].isna().sum()))
# Out:
# Number of instances = 3018
# Number of attributes = 36
# Number of missing values:
# 	long: 0
# 	lat: 0
# 	unique_squirrel_id: 0
# 	hectare: 0
# 	shift: 0
# 	date: 0
# 	hectare_squirrel_number: 0
# 	age: 121
# 	primary_fur_color: 55
# 	highlight_fur_color: 1085
# 	combination_of_primary_and_highlight_color: 0
# 	color_notes: 2836
# 	location: 64
# 	above_ground_sighter_measurement: 114
# 	specific_location: 2543
# 	running: 0
# 	chasing: 0
# 	climbing: 0
# 	eating: 0
# 	foraging: 0
# 	other_activities: 2581
# 	kuks: 0
# 	quaas: 0
# 	moans: 0
# 	tail_flags: 0
# 	tail_twitches: 0
# 	approaches: 0
# 	indifferent: 0
# 	runs_from: 0
# 	other_interactions: 2779
# 	lat_long: 0
# 	zip_codes: 3009
# 	community_districts: 0
# 	borough_boundaries: 0
# 	city_council_districts: 0
# 	police_precincts: 0

# %%
columns_to_drop = ['specific_location', 'highlight_fur_color', 'specific_location','other_activities','other_interactions','zip_codes','color_notes']
data = data.drop(columns=columns_to_drop)

# %%
data
# Out:
#            long        lat unique_squirrel_id hectare shift      date  \
# 0    -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1    -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2    -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3    -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4    -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
# ...         ...        ...                ...     ...   ...       ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       hectare_squirrel_number       age primary_fur_color  \
# 0                           3       NaN               NaN
# 1                           3     Adult              Gray
# 2                           3     Adult          Cinnamon
# 3                           5  Juvenile              Gray
# 4                           1       NaN               NaN
# ...                       ...       ...               ...
# 3018                        4     Adult              Gray
# 3019                        5     Adult              Gray
# 3020                        7     Adult              Gray
# 3021                        2       NaN              Gray
# 3022                        1     Adult          Cinnamon
#
#      combination_of_primary_and_highlight_color  ... tail_flags tail_twitches  \
# 0                                             +  ...      False         False
# 1                                 Gray+Cinnamon  ...      False         False
# 2                                     Cinnamon+  ...      False         False
# 3                                         Gray+  ...      False         False
# 4                                             +  ...      False         False
# ...                                         ...  ...        ...           ...
# 3018                                      Gray+  ...      False         False
# 3019                                 Gray+White  ...      False         False
# 3020                Gray+Black, Cinnamon, White  ...      False         False
# 3021                       Gray+Cinnamon, White  ...      False         False
# 3022                       Cinnamon+Gray, White  ...      False         False
#
#       approaches  indifferent  runs_from  \
# 0          False        False      False
# 1          False        False       True
# 2          False         True      False
# 3          False        False       True
# 4          False        False      False
# ...          ...          ...        ...
# 3018       False        False       True
# 3019       False         True      False
# 3020       False         True      False
# 3021       False         True      False
# 3022        True        False      False
#
#                                           lat_long  community_districts  \
# 0       POINT (-73.9561344937861 40.7940823884086)                   19
# 1     POINT (-73.9570437717691 40.794850940803904)                   19
# 2      POINT (-73.9768311751004 40.76671780725581)                   19
# 3       POINT (-73.9757249834141 40.7697032606755)                   19
# 4        POINT (-73.9593126695714 40.797533370163)                   19
# ...                                            ...                  ...
# 3018    POINT (-73.9639431360458 40.7908677445466)                   19
# 3019    POINT (-73.9704015859639 40.7825600069973)                   19
# 3020    POINT (-73.9665871993517 40.7836775064883)                   19
# 3021    POINT (-73.9639941227864 40.7899152327912)                   19
# 3022    POINT (-73.9754794191553 40.7696404489025)                   19
#
#       borough_boundaries  city_council_districts  police_precincts
# 0                      4                      19                13
# 1                      4                      19                13
# 2                      4                      19                13
# 3                      4                      19                13
# 4                      4                      19                13
# ...                  ...                     ...               ...
# 3018                   4                      19                13
# 3019                   4                      19                13
# 3020                   4                      19                13
# 3021                   4                      19                13
# 3022                   4                      19                13
#
# [3018 rows x 30 columns]

# %%
print('Number of rows in original data = %d' % (data.shape[0]))

data = data.dropna()

print('Number of rows after discarding missing values = %d' % (data.shape[0]))
# Out:
# Number of rows in original data = 3018
# Number of rows after discarding missing values = 2779

# %%
#data = data.reset_index()
data
# Out:
#       index       long        lat unique_squirrel_id hectare shift      date  \
# 0         1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 1         2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 2         3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 3         5 -73.956570  40.790256     33H-AM-1019-02     33H    AM  10192018
# 4         6 -73.971974  40.769305      6G-PM-1020-02     06G    PM  10202018
# ...     ...        ...        ...                ...     ...   ...       ...
# 2774   3017 -73.964544  40.781160     21F-PM-1018-02     21F    PM  10182018
# 2775   3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 2776   3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 2777   3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 2778   3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       hectare_squirrel_number       age primary_fur_color  ... tail_flags  \
# 0                           3     Adult              Gray  ...      False
# 1                           3     Adult          Cinnamon  ...      False
# 2                           5  Juvenile              Gray  ...      False
# 3                           2  Juvenile              Gray  ...      False
# 4                           2     Adult              Gray  ...      False
# ...                       ...       ...               ...  ...        ...
# 2774                        2  Juvenile          Cinnamon  ...      False
# 2775                        4     Adult              Gray  ...      False
# 2776                        5     Adult              Gray  ...      False
# 2777                        7     Adult              Gray  ...      False
# 2778                        1     Adult          Cinnamon  ...      False
#
#      tail_twitches approaches  indifferent  runs_from  \
# 0            False      False        False       True
# 1            False      False         True      False
# 2            False      False        False       True
# 3            False      False        False      False
# 4            False      False         True      False
# ...            ...        ...          ...        ...
# 2774         False      False        False       True
# 2775         False      False        False       True
# 2776         False      False         True      False
# 2777         False      False         True      False
# 2778         False       True        False      False
#
#                                           lat_long  community_districts  \
# 0     POINT (-73.9570437717691 40.794850940803904)                   19
# 1      POINT (-73.9768311751004 40.76671780725581)                   19
# 2       POINT (-73.9757249834141 40.7697032606755)                   19
# 3       POINT (-73.9565700386162 40.7902561000937)                   19
# 4       POINT (-73.9719735582476 40.7693045133578)                   19
# ...                                            ...                  ...
# 2774    POINT (-73.9645437409662 40.7811599933331)                   19
# 2775    POINT (-73.9639431360458 40.7908677445466)                   19
# 2776    POINT (-73.9704015859639 40.7825600069973)                   19
# 2777    POINT (-73.9665871993517 40.7836775064883)                   19
# 2778    POINT (-73.9754794191553 40.7696404489025)                   19
#
#       borough_boundaries  city_council_districts  police_precincts
# 0                      4                      19                13
# 1                      4                      19                13
# 2                      4                      19                13
# 3                      4                      19                13
# 4                      4                      19                13
# ...                  ...                     ...               ...
# 2774                   4                      19                13
# 2775                   4                      19                13
# 2776                   4                      19                13
# 2777                   4                      19                13
# 2778                   4                      19                13
#
# [2779 rows x 31 columns]
